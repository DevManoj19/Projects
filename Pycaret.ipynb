# %% [markdown]
# <a href="https://colab.research.google.com/github/DevManoj19/Projects/blob/main/Pycaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
print("installed pycarret successfully")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 43.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 20.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 87.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 63.4 MB/s eta 0:00:00
# ...

# %%
from pycaret.datasets import get_data

# %%
dataset = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
ds = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
ds.shape
# Out:
# (768, 9)

# %%
ds.head(56)
# Out:
#     Number of times pregnant  \
# 0                          6
# 1                          1
# 2                          8
# 3                          1
# 4                          0
# 5                          5
# 6                          3
# 7                         10
# 8                          2
# 9                          8
# 10                         4
# 11                        10
# 12                        10
# 13                         1
# 14                         5
# 15                         7
# 16                         0
# 17                         7
# 18                         1
# 19                         1
# 20                         3
# 21                         8
# 22                         7
# 23                         9
# 24                        11
# 25                        10
# 26                         7
# 27                         1
# 28                        13
# 29                         5
# 30                         5
# ...

# %%
ds.loc[1:10,("Diabetes pedigree function")]
# Out:
# 1     0.351
# 2     0.672
# 3     0.167
# 4     2.288
# 5     0.201
# 6     0.248
# 7     0.134
# 8     0.158
# 9     0.232
# 10    0.191
# Name: Diabetes pedigree function, dtype: float64

# %%
ds.iloc[1:50,5]
# Out:
# 1     26.6
# 2     23.3
# 3     28.1
# 4     43.1
# 5     25.6
# 6     31.0
# 7     35.3
# 8     30.5
# 9      0.0
# 10    37.6
# 11    38.0
# 12    27.1
# 13    30.1
# 14    25.8
# 15    30.0
# 16    45.8
# 17    29.6
# 18    43.3
# 19    34.6
# 20    39.3
# 21    35.4
# 22    39.8
# 23    29.0
# 24    36.6
# 25    31.1
# 26    39.4
# 27    23.2
# 28    22.2
# 29    34.1
# 30    36.0
# 31    31.6
# 32    24.8
# 33    19.9
# 34    27.6
# 35    24.0
# 36    33.2
# 37    32.9
# 38    38.2
# 39    37.1
# 40    34.0
# 41    40.2
# 42    22.7
# 43    45.4
# 44    27.4
# 45    42.0
# 46    29.7
# 47    28.0
# 48    39.1
# 49     0.0
# Name: Body mass index (weight in kg/(height in m)^2), dtype: float64

# %%
ds.iloc[1:90,:89]
# Out:
#     Number of times pregnant  \
# 1                          1
# 2                          8
# 3                          1
# 4                          0
# 5                          5
# ..                       ...
# 85                         2
# 86                        13
# 87                         2
# 88                        15
# 89                         1
#
#     Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 1                                                  85
# 2                                                 183
# 3                                                  89
# 4                                                 137
# 5                                                 116
# ..                                                ...
# 85                                                110
# 86                                                106
# 87                                                100
# ...

# %%
y=ds.loc[101:110,['Age (years)']]
print(y)
# Out:
#      Age (years)
# 101           22
# 102           21
# 103           24
# 104           27
# 105           21
# 106           27
# 107           37
# 108           25
# 109           24
# 110           24

# %%
z=ds.loc[101:110,['Diabetes pedigree function']]
print(z)
# Out:
#      Diabetes pedigree function
# 101                       0.179
# 102                       0.262
# 103                       0.283
# 104                       0.930
# 105                       0.801
# 106                       0.207
# 107                       0.287
# 108                       0.336
# 109                       0.247
# 110                       0.199

# %%
import matplotlib.pyplot as plt

# %%
plt.plot (y,z)

# %%
import numpy as np

# %%
x=np.linspace(101,110,10)
print(x)
# Out:
# [101. 102. 103. 104. 105. 106. 107. 108. 109. 110.]

# %%
plt.plot(x,y)
plt.plot(x,z)
